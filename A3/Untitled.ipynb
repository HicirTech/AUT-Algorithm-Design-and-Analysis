# %%
import bs4
from urllib.request import urlopen as uReq
from bs4 import BeautifulSoup as soup
from PIL import Image
import requests
from io import BytesIO

# %%
def getTitle(url):
    myUrl = url
    uClient = uReq(myUrl)
    page_html = uClient.read()
    uClient.close()
    page_soup = soup(page_html,'html.parser')
    title = str(page_soup.title)[7:-8]
    print(title)

def getHyperLink(url):
    linkSet = set()
    myUrl = url
    uClient = uReq(myUrl)
    page_html = uClient.read()
    uClient.close()  
    page_soup = soup(page_html,'html.parser')
    
    all_links= page_soup.findAll('a')
    
    for link in all_links:
        
        link_Str = str(link)

        if('a href' in link_Str):
            
            link= (link_Str.split('<a href="')[1])
            link=(link.split('"')[0])

            if(('javascript:' not in link )& ('@' not in link)):
                link = fixUrl(link)
                print(link)
                linkSet.add(link)
    return linkSet

def fixUrl(url):
    if(url[0:2]=='//'):
        url =  "https:" + url 
    return url

def getImage(url):
    myUrl = url
    uClient = uReq(myUrl)
    page_html = uClient.read()
    uClient.close()  
    page_soup = soup(page_html,'html.parser')

    for img in page_soup.findAll('img'):
        response = requests.get(fixUrl(img.get("src")))
        imageBuffer = Image.open(BytesIO(response.content))
        print(f'name: {img.get("title")} , URL: {fixUrl(img.get("src"))} , width: {imageBuffer.size[0]} , height {imageBuffer.size[1]}, alt: {img.get("alt")}')


def getMeta(url):
    myUrl = url
    uClient = uReq(myUrl)
    page_html = uClient.read()
    uClient.close()  
    page_soup = soup(page_html,'html.parser')
    for meta in page_soup.findAll('meta'):
        if('description' in str(meta).lower()):
            print(f"description: {meta.get('content')}")
        if('keyword' in str(meta).lower()):
            print(f"keyword: {meta.get('content')}")

# %%
     getTitle("https://www.newegg.com/global/nz")
     getHyperLink("https://www.newegg.com/global/nz")
     getImage("https://www.newegg.com/global/nz")
     getMeta("https://www.newegg.com/global/nz")
# Out:
# Computer parts, laptops, electronics, and more - Newegg New Zealand
# https://www.newegg.com/global/nz
# https://secure.newegg.com/WishList/MyWishlists
# https://secure.newegg.com/WishList/FollowWishlists
# https://secure.newegg.com/WishList/PublicWishlists
# https://secure.newegg.com/Guest/OrderLogin.aspx?Source=1
# https://secure.newegg.com/Guest/OrderLogin.aspx?Source=4
# https://secure.newegg.com/Guest/OrderLogin.aspx?Source=2
# https://secure.newegg.com/Guest/OrderLogin.aspx?Source=3
# https://www.newegg.com/Special/Rebate.aspx?name=Rebate-Center
# https://kb.newegg.com/
# https://www.newegg.com/global/NZ/Components/Store/ID-1
# https://www.newegg.com/global/NZ/Laptops-Notebooks/Category/ID-223
# https://www.newegg.com/global/NZ/Home-Appliances/Category/ID-312
# https://www.newegg.com/global/NZ/Product/ProductList.aspx?Submit=ENE&amp;Category=119
# https://www.newegg.com/global/NZ/Computer-Accessories/Category/ID-1
# https://www.newegg.com/global/NZ/Cell-Phones/Category/ID-450
# https://kb.newegg.com/
# https://secure.newegg.com/Guest/OrderLogin.aspx?Source=1
# https://secure.newegg.com/Guest/OrderLogin.aspx?Source=2
# https://kb.newegg.com/Article/Index/12/3?id=1167
# https://kb.newegg.com/Article/Index/12/3?id=1166
# name: CRYORIG H7 Tower Cooler For AMD/Intel CPU with 120mm PWM Fan , URL: https://c1.neweggimages.com/ProductImageCompressAll300/A4UF_1308694239703545452FFVmY5Uvn.jpg , width: 300 , height 225, alt: CRYORIG H7 Tower Cooler For AMD/Intel CPU with 120mm PWM Fan
# name: AMD RYZEN 7 2700X 8-Core 3.7 GHz (4.3 GHz Max Boost) Socket AM4 105W YD270XBGAFBOX Desktop Processor , URL: https://c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/19-113-499-V01.jpg , width: 300 , height 225, alt: AMD RYZEN 7 2700X 8-Core 3.7 GHz (4.3 GHz Max Boost) Socket AM4 105W YD270XBGAFBOX Desktop Processor
# name: Acer ED242QR Abidpx Black 24" 144Hz AMD FreeSync VA Curved Widescreen LED backlight Monitor, HDMI, DisplayPort, Tilt , URL: https://c1.neweggimages.com/NeweggImage/ProductImageCompressAll300/24-011-162-V08.jpg , width: 300 , height 225, alt: Acer ED242QR Abidpx Black 24" 144Hz AMD FreeSync VA Curved Widescreen LED backlight Monitor, HDMI, DisplayPort, Tilt
# name: DIY Hardware , URL: https://images10.newegg.com/ProductImageCompressAll180/11-133-244-41.jpg , width: 180 , height 135, alt: DIY Hardware
# name: Laptops , URL: https://images10.newegg.com/ProductImageCompressAll180/A8X5_131058525764839488GVB8iSbB5E.jpg , width: 180 , height 135, alt: Laptops
# name: Small Appliance , URL: https://images10.newegg.com/ProductImageCompressAll180/96-110-022-11.jpg , width: 180 , height 135, alt: Small Appliance
# name: SSDS , URL: https://images10.newegg.com/ProductImageCompressAll180/20-721-108-02.jpg , width: 180 , height 135, alt: SSDS
# name: COMPUTER ACCESSORIES , URL: https://images10.newegg.com/ProductImageCompressAll180/35-608-044_R01.jpg , width: 180 , height 135, alt: COMPUTER ACCESSORIES
# name: MOBILE PHONES & ACCESSORIES , URL: https://images10.newegg.com/ProductImageCompressAll180/75-100-554-02.jpg , width: 180 , height 135, alt: MOBILE PHONES & ACCESSORIES
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/loading16.gif , width: 16 , height 16, alt: LOADING...
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/loading16.gif , width: 16 , height 16, alt: LOADING...
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/awards_04.gif , width: 79 , height 56, alt: VeriSign
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/resellerRatings_105x75.gif , width: 103 , height 73, alt: Reseller Ratings
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/blue-seal-newegginc.png , width: 96 , height 50, alt: Click for the BBB Business Review of this Computers - Supplies & Parts in Whittier CA
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/inc500.gif , width: 54 , height 62, alt: Inc500
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/none.gif , width: 1 , height 1, alt: More Information
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/none.gif , width: 1 , height 1, alt: close
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/loading16.gif , width: 16 , height 16, alt: loading
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/none.gif , width: 1 , height 1, alt:
# name: None , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/none.gif , width: 1 , height 1, alt: close window
# name:  , URL: https://c1.neweggimages.com/WebResource/Themes/2005/Nest/Gomeznone4.gif , width: 1 , height 1, alt:
# keyword: Computer parts, laptops, electronics
# description: Newegg is proud to offer New Zealand the best prices, fast shipping & top-rated customer service for Computer Parts, Laptops, Electronics and more!
# description: Newegg is proud to offer New Zealand the best prices, fast shipping & top-rated customer service for Computer Parts, Laptops, Electronics and more!
